# %% [markdown]
# ## Загружаем необходимые библиотеки

# %%
import os

import random
import pandas as pd
import numpy as np
import shutil
from tqdm import tqdm

import matplotlib
import plotly
import PIL
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

import yaml
import torch
import json
from bs4 import BeautifulSoup
import xml.etree.ElementTree as ET

from sklearn.model_selection import train_test_split

# %% [markdown]
# Загрузка YOLO5

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16117, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 16117 (delta 9), reused 11 (delta 1), pack-reused 16089
# Receiving objects: 100% (16117/16117), 14.85 MiB | 19.00 MiB/s, done.
# Resolving deltas: 100% (11028/11028), done.
# /content/yolov5

# %%
# %cd /content/yolov5

# !pip install -qr requirements.txt
# !pip install -q roboflow
# Out:
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.2/663.2 kB 34.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Загрузка датасета

# %%
# !git clone 'https://github.com/MelnikDM/SVO.git'
# Out:
# Cloning into 'SVO'...
# remote: Enumerating objects: 3614, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 3614 (delta 7), reused 75 (delta 5), pack-reused 3534
# Receiving objects: 100% (3614/3614), 439.52 MiB | 40.18 MiB/s, done.
# Resolving deltas: 100% (1750/1750), done.
# Updating files: 100% (3376/3376), done.

# %%
# !python detect.py --source /content/yolov5/SVO/LA_ObjectDetection/data/Videos/nakat.mp4 --conf-thres 0.6 --weights /content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt'], source=/content/yolov5/SVO/LA_ObjectDetection/data/Videos/nakat.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20869098 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/3395) /content/yolov5/SVO/LA_ObjectDetection/data/Videos/nakat.mp4: 384x640 (no detections), 47.3ms
# ...

# %%
# !python detect.py --source /content/yolov5/SVO/LA_ObjectDetection/data/Videos/BTR4.mp4 --conf-thres 0.6 --weights /content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt'], source=/content/yolov5/SVO/LA_ObjectDetection/data/Videos/BTR4.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20869098 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/142) /content/yolov5/SVO/LA_ObjectDetection/data/Videos/BTR4.mp4: 384x640 1 MBT, 51.5ms
# video 1/1 (2/142) /content/yolov5/SVO/LA_ObjectDetection/data/Videos/BTR4.mp4: 384x640 1 MBT, 19.8ms
# ...

# %%
# !python detect.py --source /content/yolov5/SVO/LA_ObjectDetection/data/Videos/T64_Lancet.mp4 --conf-thres 0.6 --weights /content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/SVO/LA_ObjectDetection/detections/v1YOLOv5/weights/final/weights/best.pt'], source=/content/yolov5/SVO/LA_ObjectDetection/data/Videos/T64_Lancet.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-254-gba63208 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20869098 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/2661) /content/yolov5/SVO/LA_ObjectDetection/data/Videos/T64_Lancet.mp4: 384x640 (no detections), 47.8ms
# ...

# %%
# !zip -r /content/video.zip /content/yolov5/runs/detect/
# Out:
# updating: content/yolov5/runs/detect/ (stored 0%)
# updating: content/yolov5/runs/detect/exp2/ (stored 0%)
# updating: content/yolov5/runs/detect/exp3/ (stored 0%)
# updating: content/yolov5/runs/detect/exp3/T64_Lancet.mp4 (deflated 1%)
# updating: content/yolov5/runs/detect/exp/ (stored 0%)
# updating: content/yolov5/runs/detect/exp/nakat.mp4 (deflated 1%)
#   adding: content/yolov5/runs/detect/exp4/ (stored 0%)
#   adding: content/yolov5/runs/detect/exp4/BTR4.mp4 (deflated 4%)

# %%
from google.colab import files
files.download("/content/video.zip")
